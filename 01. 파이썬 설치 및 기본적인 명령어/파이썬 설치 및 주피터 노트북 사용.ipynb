# %% [markdown]
# # 예측 애널리틱스 : 파이썬 다운로드, 주피터 노트북 사용 방법

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 주피터 노트북 이용해보기

# %%
a=3
b=3
print(a+b)
# Out:
# 6

# %%
a,b = 3,5
print(a*b)
# Out:
# 15

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
def add(a,b):
    return a+b
add(3,5)
# Out:
# 8

# %% [markdown]
# ## 패키지 불러오기 및 설치해보기

# %%
import os

import pandas as pd
import pandas_datareader.data as pdr

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

import itertools

# %%
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\jinsoo\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: lxml in c:\users\jinsoo\anaconda3\lib\site-packages (from pandas_datareader) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jinsoo\anaconda3\lib\site-packages (from pandas_datareader) (2.22.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\jinsoo\anaconda3\lib\site-packages (from pandas_datareader) (1.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jinsoo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jinsoo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jinsoo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jinsoo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.8)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\jinsoo\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\jinsoo\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\jinsoo\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\users\jinsoo\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.23->pandas_datareader) (1.15.0)

# %% [markdown]
# ## 데이터 불러오기 및 분리해보기

# %% [markdown]
# ### 데이터 부르기

# %%
import pandas as pd
data = pd.read_csv('./hour.csv')

# %% [markdown]
# ### 데이터 분리해보기

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data,test_size=0.3)
print("원래 데이터 개수 : ",data.shape[0])
print("훈련 데이터 개수 : ", train.shape[0])
print("테스트 데이터 개수 : ", test.shape[0])
# Out:
# 원래 데이터 개수 :  17379
# 훈련 데이터 개수 :  12165
# 테스트 데이터 개수 :  5214
